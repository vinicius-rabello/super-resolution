# %%
import torch
import torchvision.datasets as datasets
from tqdm import tqdm
from torch import nn
from torchvision import transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F
import sys
import os
import matplotlib.pyplot as plt
import numpy as np

# adding '../ocean/src/model/' to sys.path
sys.path.append(os.path.abspath('../../ocean/src/model/'))

from model import SuperResolution

# %%
for downgrade_factor in [4, 8, 16]:
    losses = torch.load(f'../models/loss_psi1_x{downgrade_factor}_200.pt').cpu()
    losses = losses.detach().numpy()

    plt.plot(losses, label=f'Loss for downgrade factor: {downgrade_factor}')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
