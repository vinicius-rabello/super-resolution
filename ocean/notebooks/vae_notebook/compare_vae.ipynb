# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
latent_dim = [1,2,3,4, 5]
pathlist = [f"VAE_{i}" for i in latent_dim]


for dim in latent_dim:
    checkpoint = torch.load(f"../../ocean/models/VAE_{dim}/loss_vae_ld_{dim}_500.pt")
    loss = checkpoint.cpu().detach().numpy()

    plt.plot(loss, label = f"{dim}")

plt.legend()
